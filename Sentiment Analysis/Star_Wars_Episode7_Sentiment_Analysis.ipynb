# %%
# Installing python libraries
# !pip install -U textblob
# !python -m textblob.download_corpora
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 636 kB 22.4 MB/s
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.15.3
#     Uninstalling textblob-0.15.3:
#       Successfully uninstalled textblob-0.15.3
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# ...

# %%
# Importing pandas and reading in webs scraped IMDB reviews file for episode 7
import pandas as pd
star_wars_7_df = pd.read_csv("/content/INST737_Star_Wars_IMDB_StarWars7.csv")

# %%
# Prints the first few columns
star_wars_7_df.head()
# Out:
#    Unnamed: 0       Review_Date          Author  Rating  \
# 0           0   19 January 2016  Prichards12345     1.0
# 1           1   14 January 2016          mcgrew     2.0
# 2           2      7 April 2016       jaredpahl     1.0
# 3           3  19 February 2016        Searsino     2.0
# 4           4      4 April 2016     LouieInLove     3.0
#
#                                         Review_Title  \
# 0   Reboot, Sequel, Prequel, Re-Imagining Rebrand...
# 1       JJ does it again (and not in the good way)\n
# 2   Disney Sponsored Fan Fiction. The Force Awake...
# 3   Star Wars: The Force is for Everyone Apparent...
# 4   Disney's Hype Wars Won. Star Wars Did Not - A...
#
#                                               Review  \
# 0  Star Wars movies used to be great. Remember th...
# 1  You'll notice that SW7 only has a "based on ch...
# 2                     For those praising this film,
# 3  Context: I grew up on these films. I didn't th...
# ...

# %%
# Drops unneeded columns 
star_wars_7_df_v2 = star_wars_7_df.drop(columns = ["Review_Date", "Author", "Rating", "Review_Title", "Review_Url", "Unnamed: 0"])

# %%
# Prints newly edited dataframe
star_wars_7_df_v2
# Out:
#                                                  Review
# 0     Star Wars movies used to be great. Remember th...
# 1     You'll notice that SW7 only has a "based on ch...
# 2                        For those praising this film,
# 3     Context: I grew up on these films. I didn't th...
# 4     Following the mass-marketing campaign extraord...
# ...                                                 ...
# 5057  This is a Great movie and it will be the same ...
# 5058  First of all, as a huge Star Wars fan, I find ...
# 5059  She lied. No wrist, only me trying leave her. ...
# 5060  This movie is flawed, to say the least. Most o...
# 5061  If you've ever wished there was a version of S...
#
# [5062 rows x 1 columns]

# %%
# Test block to see if review gets printed
reviewParagraph = ""
for review in star_wars_7_df_v2['Review'][:1]:
  reviewParagraph = review

# %%
# Prints results from previous test for loop 
reviewParagraph
# Out:
# 'Star Wars movies used to be great. Remember that? Remember how they inspired a generation of loyal fans? Remember how they virtually saved cinema from terminal audience decline in the 70s? So scoot forward 40 years, and see the empty soulless rubbish lapped up by brainwashed Pavlovian audiences and critics. How much did Disney pay the critics for all those gushing reviews? Either that or the art of film criticism has been lost.'

# %%
# Imports TextBlob
from textblob import TextBlob
blob = TextBlob(reviewParagraph)

# %%
# This block was used for testing purposes to see if the first review's sentiment and polarity would get displayed
blob.sentiment
# Out:
# Sentiment(polarity=0.3083333333333333, subjectivity=0.5708333333333334)

# %%
# Creates dataframe that will be used to get the sentiment and polarity of all star wars episode 7 reviews
star_wars_episode_7_final_df = pd.DataFrame(columns = ['Review', 'Polarity', 'Subjectivity'])

# %%
# Checks to see if dataframe was created with the columns created above 
star_wars_episode_7_final_df
# Out:
# Empty DataFrame
# Columns: [Review, Polarity, Subjectivity]
# Index: []

# %%
# This block would give the polarity and subjectivity of all reviews for Star Wars episode 7
star_wars_review_list = []
star_wars_polarity_list = []
star_wars_subjectivity_list = []

for review in star_wars_7_df_v2['Review']:
  blob = TextBlob(str(review))
  star_wars_review_list.append(review)
  star_wars_polarity_list.append(blob.sentiment.polarity)
  star_wars_subjectivity_list.append(blob.sentiment.subjectivity)



star_wars_episode_7_final_df['Review'] = star_wars_review_list
star_wars_episode_7_final_df['Polarity'] = star_wars_polarity_list
star_wars_episode_7_final_df['Subjectivity'] = star_wars_subjectivity_list


star_wars_episode_7_final_df = star_wars_episode_7_final_df[['Review', 'Polarity', 'Subjectivity']]
  
star_wars_episode_7_final_df.head()
# Out:
#                                               Review  Polarity  Subjectivity
# 0  Star Wars movies used to be great. Remember th...  0.308333      0.570833
# 1  You'll notice that SW7 only has a "based on ch...  0.222630      0.616266
# 2                     For those praising this film,   0.000000      0.000000
# 3  Context: I grew up on these films. I didn't th...  0.275000      0.505556
# 4  Following the mass-marketing campaign extraord...  0.250000      0.500000

# %%
# Converting dataframe to csv 
# Code down below was commented out because file already created 
# star_wars_episode7_final_df.to_csv('Star_Wars_Episode7_Sentiment_Analysis.csv’)

# %%
# Reviews that have a polarity greater than 0 go to a positive dataframe
positive_df = star_wars_episode_7_final_df[star_wars_episode_7_final_df['Polarity'] > 0]
positive_df
# Out:
#                                                  Review  Polarity  \
# 0     Star Wars movies used to be great. Remember th...  0.308333
# 1     You'll notice that SW7 only has a "based on ch...  0.222630
# 3     Context: I grew up on these films. I didn't th...  0.275000
# 4     Following the mass-marketing campaign extraord...  0.250000
# 5     Sad but true. When the opening credits filled ...  0.142593
# ...                                                 ...       ...
# 5056  This is not a detailed review. While I liked t...  0.244118
# 5057  This is a Great movie and it will be the same ...  0.400000
# 5058  First of all, as a huge Star Wars fan, I find ...  0.304545
# 5059  She lied. No wrist, only me trying leave her. ...  0.400000
# 5060  This movie is flawed, to say the least. Most o...  0.010897
#
#       Subjectivity
# 0         0.570833
# 1         0.616266
# 3         0.505556
# 4         0.500000
# 5         0.687037
# ...            ...
# 5056      0.607773
# ...

# %%
# Reviews that have a polarity less than 0 go to a negative dataframe
negative_df = star_wars_episode_7_final_df[star_wars_episode_7_final_df['Polarity'] < 0]
negative_df
# Out:
#                                                  Review  Polarity  \
# 6     Oh how I miss the style of that awful film cal... -1.000000
# 10    I jut got just back from the cinema, watching ... -0.157500
# 26    So many possibilities to tell stories followin... -0.020099
# 31    In short: dull, stupid, unimaginative. A huge ... -0.174621
# 32    Commercial campaign for this movie: 10/10, the... -0.157041
# ...                                                 ...       ...
# 4999                      Very minor spoilers within... -0.065000
# 5012                               Sorry for my English -0.250000
# 5023  First of all let me say that the reviews of 1 ... -0.025521
# 5032  I usually just ignore IMDb reviews because usu... -0.129270
# 5034  *CONTAINS SPOILERS* As any star wars fan, or a... -0.135417
#
#       Subjectivity
# 6         1.000000
# 10        0.260000
# 26        0.531586
# 31        0.550000
# 32        0.527642
# ...            ...
# 4999      0.260000
# ...

# %%
# Creates a sample dataframe of 5 percent of positive reviews
positive_df_2 = positive_df.sample(frac = .05)
# Creates a sample dataframe of 5 percent of negative reviews
negative_df_2 = negative_df.sample(frac = .05)

# %%
# Converts positive dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\Star_Wars_Episode7_Positive_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# positive_df_2.to_csv(index=False)
# positive_df_2.to_csv(filepath)

# %%
# Converts negative dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\Star_Wars_Episode_7_Negative_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# negative_df_2.to_csv(index=False)
# negative_df_2.to_csv(filepath)
