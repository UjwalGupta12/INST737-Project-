# %%
# Installing python libraries
# !pip install -U textblob
# !python -m textblob.download_corpora
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 636 kB 4.8 MB/s
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.15.3
#     Uninstalling textblob-0.15.3:
#       Successfully uninstalled textblob-0.15.3
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# ...

# %%
# Importing pandas and reading in webs scraped IMDB reviews file for episode 5
import pandas as pd
star_wars_5_df = pd.read_csv("/content/INST737_Star_Wars_IMDB_StarWars5.csv")

# %%
# Prints the first few columns
star_wars_5_df.head()
# Out:
#    Unnamed: 0      Review_Date          Author  Rating  \
# 0           0    25 April 2016      ivo-cobra8    10.0
# 1           1     27 June 2002     bob the moo     NaN
# 2           2   7 October 2004          TxMike     NaN
# 3           3  26 October 1999          Spleen    10.0
# 4           4  16 January 2020  UniqueParticle    10.0
#
#                                         Review_Title  \
# 0   Excellent timeless classic, the best sequel o...
# 1   All the fun of the original with a much bette...
# 2   A worthy second (or 5th??) Star Wars installm...
# 3   It's NOT the darkest of the trilogy - it's th...
# 4            I enjoy this one more than A New Hope\n
#
#                                               Review  \
# 0  Star Wars: Episode V - The Empire Strikes Back...
# 1  The Rebellion has struck an important blow to ...
# 2  My five children were all pre-teens when 'The ...
# 3  `It avoids having the standard shoot-'em-up en...
# ...

# %%
# Drops unneeded columns 
star_wars_5_df_v2 = star_wars_5_df.drop(columns = ["Review_Date", "Author", "Rating", "Review_Title", "Review_Url", "Unnamed: 0"])

# %%
# Prints newly edited dataframe
star_wars_5_df_v2
# Out:
#                                                  Review
# 0     Star Wars: Episode V - The Empire Strikes Back...
# 1     The Rebellion has struck an important blow to ...
# 2     My five children were all pre-teens when 'The ...
# 3     `It avoids having the standard shoot-'em-up en...
# 4     So much amazing action and beautiful cinematog...
# ...                                                 ...
# 1404  This is the one of best movie I have ever seen...
# 1405  GOOD ACTION AND MOVIE...... THIS MOVIE WORTH T...
# 1406  Indeed a timeless classic the pioneeri in scie...
# 1407  This still has to be my favorite Star Wars mov...
# 1408  I could watch it over and over again. I even n...
#
# [1409 rows x 1 columns]

# %%
# Test block to see if review gets printed
reviewParagraph = ""
for review in star_wars_5_df_v2['Review'][:1]:
  reviewParagraph = review

# %%
# Prints results from previous test for loop 
reviewParagraph
# Out:
# 'Star Wars: Episode V - The Empire Strikes Back (1980) is an excellent timeless classic that it is the best sequel of all time. I love this film to death, it is my second favorite film and the best sequel in the Star Wars franchise that I love. The Empire Strikes Back is a movie that it is one of the best sequels I can think of, it is right there with Aliens (1986), it is right there with Terminator 2: Judgment Day (1991) it is an excellent sequel and it really does establish The Empire as a value treat. Empire Strikes Back is still and excellent film which I really believe is a timeless classic. This is my second favorite film from director Irvin Kershner. Number 1 favorite Irvin Kershner film will be RoboCop 2 (1990) which is very underrated action flick. I still have to review those movies someday.'

# %%
# Imports TextBlob
from textblob import TextBlob
blob = TextBlob(reviewParagraph)

# %%
# This block was used for testing purposes to see if the first review's sentiment and polarity would get displayed
blob.sentiment
# Out:
# Sentiment(polarity=0.4210317460317459, subjectivity=0.4293650793650794)

# %%
# Creates dataframe that will be used to get the sentiment and polarity of all star wars episode 5 reviews
star_wars_episode_5_final_df = pd.DataFrame(columns = ['Review', 'Polarity', 'Subjectivity'])

# %%
# Checks to see if dataframe was created with the columns created above 
star_wars_episode_5_final_df
# Out:
# Empty DataFrame
# Columns: [Review, Polarity, Subjectivity]
# Index: []

# %%
# This block would give the polarity and subjectivity of all reviews for Star Wars episode 5
star_wars_review_list = []
star_wars_polarity_list = []
star_wars_subjectivity_list = []

for review in star_wars_5_df_v2['Review']:
  blob = TextBlob(str(review))
  star_wars_review_list.append(review)
  star_wars_polarity_list.append(blob.sentiment.polarity)
  star_wars_subjectivity_list.append(blob.sentiment.subjectivity)



star_wars_episode_5_final_df['Review'] = star_wars_review_list
star_wars_episode_5_final_df['Polarity'] = star_wars_polarity_list
star_wars_episode_5_final_df['Subjectivity'] = star_wars_subjectivity_list


star_wars_episode_5_final_df = star_wars_episode_5_final_df[['Review', 'Polarity', 'Subjectivity']]
  
star_wars_episode_5_final_df.head()
# Out:
#                                               Review  Polarity  Subjectivity
# 0  Star Wars: Episode V - The Empire Strikes Back...  0.421032      0.429365
# 1  The Rebellion has struck an important blow to ... -0.000216      0.519264
# 2  My five children were all pre-teens when 'The ...  0.213393      0.525000
# 3  `It avoids having the standard shoot-'em-up en...  0.115385      0.394231
# 4  So much amazing action and beautiful cinematog...  0.382051      0.512821

# %%
# Converting dataframe to csv 
# Code down below was commented out because file already created 
# star_wars_episode5_final_df.to_csv('Star_Wars_Episode5_Sentiment_Analysis.csv’)

# %%
# Reviews that have a polarity greater than 0 go to a positive dataframe
positive_df = star_wars_episode_5_final_df[star_wars_episode_5_final_df['Polarity'] > 0]
positive_df
# Out:
#                                                  Review  Polarity  \
# 0     Star Wars: Episode V - The Empire Strikes Back...  0.421032
# 2     My five children were all pre-teens when 'The ...  0.213393
# 3     `It avoids having the standard shoot-'em-up en...  0.115385
# 4     So much amazing action and beautiful cinematog...  0.382051
# 5     In a film like The Empire Strikes Back, especi...  0.126389
# ...                                                 ...       ...
# 1404  This is the one of best movie I have ever seen...  0.591667
# 1405  GOOD ACTION AND MOVIE...... THIS MOVIE WORTH T...  0.275000
# 1406  Indeed a timeless classic the pioneeri in scie...  0.166667
# 1407  This still has to be my favorite Star Wars mov...  0.402637
# 1408  I could watch it over and over again. I even n...  0.500000
#
#       Subjectivity
# 0         0.429365
# 2         0.525000
# 3         0.394231
# 4         0.512821
# 5         0.413360
# ...            ...
# 1404      0.525000
# ...

# %%
# Reviews that have a polarity less than 0 go to a negative dataframe
negative_df = star_wars_episode_5_final_df[star_wars_episode_5_final_df['Polarity'] < 0]
negative_df
# Out:
#                                                  Review  Polarity  \
# 1     The Rebellion has struck an important blow to ... -0.000216
# 6     After the destruction of the Death Star, the R... -0.666667
# 13    The rebels' new base is hidden in the icy plan... -0.103788
# 16    The Empire Strikes Back (1980) is a movie in m... -0.087662
# 18    Congratulations have to go to line producer Ga... -0.051768
# ...                                                 ...       ...
# 1299  Fight scenes are too amateur. Concept is good.... -0.016667
# 1300  This part of the saga is the only way to under... -0.030000
# 1311  What can I tell about this Fifth episode of th... -0.017824
# 1319  Can anyone explain why in the new star wars, t... -0.046364
# 1402  Dark, sinister, raw and revealing - you´ll lov... -0.003031
#
#       Subjectivity
# 1         0.519264
# 6         0.900000
# 13        0.435985
# 16        0.350649
# 18        0.665404
# ...            ...
# 1299      0.616667
# ...

# %%
# Creates a sample dataframe of 5 percent of positive reviews
positive_df_2 = positive_df.sample(frac = .05)
# Creates a sample dataframe of 5 percent of negative reviews
negative_df_2 = negative_df.sample(frac = .05)

# %%
# Converts positive dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\Star_Wars_Episode_5_Positive_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# positive_df_2.to_csv(index=False)
# positive_df_2.to_csv(filepath)

# %%
# Converts negative dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\Star_Wars_Episode_5_Negative_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# negative_df_2.to_csv(index=False)
# negative_df_2.to_csv(filepath)
