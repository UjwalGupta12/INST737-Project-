# %%
# Installing python libraries
# !pip install -U textblob
# !python -m textblob.download_corpora
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 636 kB 5.0 MB/s
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.15.3
#     Uninstalling textblob-0.15.3:
#       Successfully uninstalled textblob-0.15.3
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# ...

# %%
# Importing pandas and reading in webs scraped IMDB reviews file for episode 4
import pandas as pd
star_wars_4_df = pd.read_csv("/content/INST737_Star_Wars_IMDB_StarWars4.csv")

# %%
# Prints the first few columns
star_wars_4_df.head()
# Out:
#    Unnamed: 0       Review_Date              Author  Rating  \
# 0           0   26 October 2003  FiendishDramaturgy    10.0
# 1           1     23 April 2016          ivo-cobra8    10.0
# 2           2   16 January 2020      UniqueParticle    10.0
# 3           3  25 December 2005          Bogmeister     9.0
# 4           4     31 March 2003        mentalcritic     NaN
#
#                                         Review_Title  \
# 0   One of the most successful movies of all time...
# 1   A classics, phenomenal and arguably the best ...
# 2                        Legendary piece of cinema\n
# 3   The Best of Sci-Fi Times,the Worst of sf Times\n
# 4            The original version was brilliant...\n
#
#                                               Review  \
# 0  What made this the hugely successful triumph i...
# 1  Star Wars: Episode IV - A New Hope (1977) is a...
# 2  Only seen the original Star Wars films a few t...
# 3  Though now known as "Episode IV-A New Hope," f...
# ...

# %%
# Drops unneeded columns 
star_wars_4_df_v2 = star_wars_4_df.drop(columns = ["Review_Date", "Author", "Rating", "Review_Title", "Review_Url", "Unnamed: 0"])

# %%
# Prints newly edited dataframe
star_wars_4_df_v2
# Out:
#                                                  Review
# 0     What made this the hugely successful triumph i...
# 1     Star Wars: Episode IV - A New Hope (1977) is a...
# 2     Only seen the original Star Wars films a few t...
# 3     Though now known as "Episode IV-A New Hope," f...
# 4     I was actually born about a year after this fi...
# ...                                                 ...
# 2052  Great movie, ive watched it millions of times ...
# 2053  Is this a great film, probably not. However it...
# 2054  I personaly like this movie the most because i...
# 2055  Star Wars: Episode IV - A New Hope follows the...
# 2056  It's near impossible to select a favorite from...
#
# [2057 rows x 1 columns]

# %%
# Test block to see if review gets printed
reviewParagraph = ""
for review in star_wars_4_df_v2['Review'][:1]:
  reviewParagraph = review

# %%
# Prints results from previous test for loop 
reviewParagraph
# Out:
# 'What made this the hugely successful triumph it was? Was it casting, music, imagination, ingenuity, or luck?'

# %%
# Imports TextBlob
from textblob import TextBlob
blob = TextBlob(reviewParagraph)

# %%
# This block was used for testing purposes to see if the first review's sentiment and polarity would get displayed
blob.sentiment
# Out:
# Sentiment(polarity=0.75, subjectivity=0.95)

# %%
# Creates dataframe that will be used to get the sentiment and polarity of all star wars episode 4 reviews
star_wars_episode_4_final_df = pd.DataFrame(columns = ['Review', 'Polarity', 'Subjectivity'])

# %%
# Checks to see if dataframe was created with the columns created above 
star_wars_episode_4_final_df
# Out:
# Empty DataFrame
# Columns: [Review, Polarity, Subjectivity]
# Index: []

# %%
# This block would give the polarity and subjectivity of all reviews for Star Wars episode 4
star_wars_review_list = []
star_wars_polarity_list = []
star_wars_subjectivity_list = []

for review in star_wars_4_df_v2['Review']:
  blob = TextBlob(str(review))
  star_wars_review_list.append(review)
  star_wars_polarity_list.append(blob.sentiment.polarity)
  star_wars_subjectivity_list.append(blob.sentiment.subjectivity)



star_wars_episode_4_final_df['Review'] = star_wars_review_list
star_wars_episode_4_final_df['Polarity'] = star_wars_polarity_list
star_wars_episode_4_final_df['Subjectivity'] = star_wars_subjectivity_list


star_wars_episode_4_final_df = star_wars_episode_4_final_df[['Review', 'Polarity', 'Subjectivity']]
  
star_wars_episode_4_final_df.head()
# Out:
#                                               Review  Polarity  Subjectivity
# 0  What made this the hugely successful triumph i...  0.750000      0.950000
# 1  Star Wars: Episode IV - A New Hope (1977) is a...  0.215419      0.562834
# 2  Only seen the original Star Wars films a few t...  0.257219      0.653476
# 3  Though now known as "Episode IV-A New Hope," f...  0.106004      0.508987
# 4  I was actually born about a year after this fi...  0.040000      0.496667

# %%
# Converting dataframe to csv 
# Code down below was commented out because file already created 
# star_wars_episode1_final_df.to_csv('Star_Wars_Episode4_Sentiment_Analysis.csv’)

# %%
# Reviews that have a polarity greater than 0 go to a positive dataframe
positive_df = star_wars_episode_4_final_df[star_wars_episode_4_final_df['Polarity'] > 0]
positive_df
# Out:
#                                                  Review  Polarity  \
# 0     What made this the hugely successful triumph i...  0.750000
# 1     Star Wars: Episode IV - A New Hope (1977) is a...  0.215419
# 2     Only seen the original Star Wars films a few t...  0.257219
# 3     Though now known as "Episode IV-A New Hope," f...  0.106004
# 4     I was actually born about a year after this fi...  0.040000
# ...                                                 ...       ...
# 2052  Great movie, ive watched it millions of times ...  0.450000
# 2053  Is this a great film, probably not. However it...  0.361905
# 2054  I personaly like this movie the most because i...  0.531250
# 2055  Star Wars: Episode IV - A New Hope follows the...  0.125821
# 2056  It's near impossible to select a favorite from...  0.063889
#
#       Subjectivity
# 0         0.950000
# 1         0.562834
# 2         0.653476
# 3         0.508987
# 4         0.496667
# ...            ...
# 2052      0.475000
# ...

# %%
# Reviews that have a polarity less than 0 go to a negative dataframe
negative_df = star_wars_episode_4_final_df[star_wars_episode_4_final_df['Polarity'] < 0]
negative_df
# Out:
#                                                  Review  Polarity  \
# 11    This story happened 'A long time ago in a gala... -0.008333
# 19    Star Wars seems to lack the sense of importanc... -0.355000
# 21    The Republic has fallen and the Empire rules t... -0.059091
# 22    The film turn on the endlessly renewed battle ... -0.085000
# 29    During the attack of the Empire's forces under... -0.022727
# ...                                                 ...       ...
# 1908  After the disappointment of TPM, a diassapoint... -0.086728
# 1931  All Star Wars movies suck. The only reason why... -0.081548
# 1967  I believe that every film must be recognized w... -0.062500
# 1979  I may of seen this movie 100 times over the pa... -0.025000
# 2031  Finding the originals is getting harder and ha... -0.063889
#
#       Subjectivity
# 11        0.783333
# 19        0.600000
# 21        0.313636
# 22        0.470000
# 29        0.495455
# ...            ...
# 1908      0.576543
# ...

# %%
# Creates a sample dataframe of 5 percent of positive reviews
positive_df_2 = positive_df.sample(frac = .05)
# Creates a sample dataframe of 5 percent of negative reviews
negative_df_2 = negative_df.sample(frac = .05)

# %%
# Converts positive dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\Star_Wars_Episode_4_Positive_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# positive_df_2.to_csv(index=False)
# positive_df_2.to_csv(filepath)

# %%
# Converts negative dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\Star_Wars_Episode_4_Negative_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# negative_df_2.to_csv(index=False)
# negative_df_2.to_csv(filepath)
