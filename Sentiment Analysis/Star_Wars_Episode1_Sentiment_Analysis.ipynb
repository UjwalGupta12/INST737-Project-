# %%
# Installing python libraries
# !pip install -U textblob
# !python -m textblob.download_corpora
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 636 kB 7.6 MB/s
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.15.3
#     Uninstalling textblob-0.15.3:
#       Successfully uninstalled textblob-0.15.3
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# ...

# %%
# Importing pandas and reading in webs scraped IMDB reviews file for episode 1
import pandas as pd
star_wars_1_df = pd.read_csv("/INST737_Star_Wars_IMDB_StarWars1.csv")

# %%
# Prints the first few columns
star_wars_1_df.head()
# Out:
#    Unnamed: 0       Review_Date             Author  Rating  \
# 0           0   29 October 2005            kylopod     5.0
# 1           1     31 March 2021            Toph-22     8.0
# 2           2   24 October 2009  TheLittleSongbird     7.0
# 3           3   1 December 2015          jaredpahl     9.0
# 4           4  29 December 2015     laura_brady_au     8.0
#
#                                         Review_Title  \
# 0   A perspective after all the hype has died down\n
# 1   Can supposedly not live up to the high expect...
# 2   Visually a marvel to look at, disappointing i...
# 3   The Beginning of the Star Wars Saga Introduce...
# 4   recently rewatched and it's a pretty decent s...
#
#                                               Review  \
# 0  Lucas may have problems as a director and writ...
# 1  'Star Wars: Episode I - The Phantom Menace'. A...
# 2  Star Wars: Episode 1- The Phantom Menace is de...
# 3  While it received generally positive reviews u...
# ...

# %%
# Drops unneeded columns 
star_wars_1_df_v2 = star_wars_1_df.drop(columns = ["Review_Date", "Author", "Rating", "Review_Title", "Review_Url", "Unnamed: 0"])

# %%
# Prints newly edited dataframe
star_wars_1_df_v2
# Out:
#                                                  Review
# 0     Lucas may have problems as a director and writ...
# 1     'Star Wars: Episode I - The Phantom Menace'. A...
# 2     Star Wars: Episode 1- The Phantom Menace is de...
# 3     While it received generally positive reviews u...
# 4     I recently rewatched everything Star Wars incl...
# ...                                                 ...
# 3985  Okay, I was way late to the party on this movi...
# 3986  Star Wars is one of my favorite movie franchis...
# 3987  I went to see this film during it's first rele...
# 3988  The plot was engaging I felt like I knew the c...
# 3989  Jar Jar Binks is the best charcter ever seen o...
#
# [3990 rows x 1 columns]

# %%
# Test block to see if review gets printed
reviewParagraph = ""
for review in star_wars_1_df_v2['Review'][:1]:
  reviewParagraph = review

# %%
# Prints results from previous test for loop 
reviewParagraph
# Out:
# 'Lucas may have problems as a director and writer, but I\'ve always thought that those flaws are balanced by his great storytelling ability. The problem with "The Phantom Menace" is that he simply has no story to tell. The film merely adds an introductory chapter to a story that has already been told, and stretches it out into a two-hour movie. It is no accident that prequels of this kind are rare. They are very difficult to make properly. And apparently he\'s just not a sophisticated enough filmmaker to pull it off.'

# %%
# Imports TextBlob
from textblob import TextBlob
blob = TextBlob(reviewParagraph)

# %%
# This block was used for testing purposes to see if the first review's sentiment and polarity would get displayed
blob.sentiment
# Out:
# Sentiment(polarity=0.034999999999999996, subjectivity=0.6357142857142856)

# %%
# Creates dataframe that will be used to get the sentiment and polarity of all star wars episode 1 reviews
star_wars_episode_1_final_df = pd.DataFrame(columns = ['Review', 'Polarity', 'Subjectivity'])

# %%
# Checks to see if dataframe was created with the columns created above 
star_wars_episode_1_final_df
# Out:
# Empty DataFrame
# Columns: [Review, Polarity, Subjectivity]
# Index: []

# %%
# This block would give the polarity and subjectivity of all reviews for Star Wars episode 1
star_wars_review_list = []
star_wars_polarity_list = []
star_wars_subjectivity_list = []

for review in star_wars_1_df_v2['Review']:
  blob = TextBlob(str(review))
  star_wars_review_list.append(review)
  star_wars_polarity_list.append(blob.sentiment.polarity)
  star_wars_subjectivity_list.append(blob.sentiment.subjectivity)



star_wars_episode_1_final_df['Review'] = star_wars_review_list
star_wars_episode_1_final_df['Polarity'] = star_wars_polarity_list
star_wars_episode_1_final_df['Subjectivity'] = star_wars_subjectivity_list


star_wars_episode_1_final_df = star_wars_episode_1_final_df[['Review', 'Polarity', 'Subjectivity']]
  
star_wars_episode_1_final_df.head()
# Out:
#                                               Review  Polarity  Subjectivity
# 0  Lucas may have problems as a director and writ...  0.035000      0.635714
# 1  'Star Wars: Episode I - The Phantom Menace'. A...  0.146591      0.651136
# 2  Star Wars: Episode 1- The Phantom Menace is de...  0.285485      0.537948
# 3  While it received generally positive reviews u...  0.141658      0.700719
# 4  I recently rewatched everything Star Wars incl...  0.000000      0.250000

# %%
# Converting dataframe to csv
# Code down below was commented out because file already created 
# star_wars_episode1_final_df.to_csv('Star_Wars_Episode1_Sentiment_Analysis.csv’)

# %%
# Reviews that have a polarity greater than 0 go to a positive dataframe
positive_df = star_wars_episode_1_final_df[star_wars_episode_1_final_df['Polarity'] > 0]
positive_df
# Out:
#                                                  Review  Polarity  \
# 0     Lucas may have problems as a director and writ...  0.035000
# 1     'Star Wars: Episode I - The Phantom Menace'. A...  0.146591
# 2     Star Wars: Episode 1- The Phantom Menace is de...  0.285485
# 3     While it received generally positive reviews u...  0.141658
# 7     Honestly I don't get it why so many people hat...  0.182331
# ...                                                 ...       ...
# 3982  Am I supposed to think it a coincidence that J...  0.099324
# 3983  Although Jar-Jar and Anakin are incredibly ann...  0.231818
# 3986  Star Wars is one of my favorite movie franchis...  0.145833
# 3988  The plot was engaging I felt like I knew the c...  0.550000
# 3989  Jar Jar Binks is the best charcter ever seen o...  0.271591
#
#       Subjectivity
# 0         0.635714
# 1         0.651136
# 2         0.537948
# 3         0.700719
# 7         0.556767
# ...            ...
# 3982      0.437698
# ...

# %%
# Reviews that have a polarity less than 0 go to a negative dataframe
negative_df = star_wars_episode_1_final_df[star_wars_episode_1_final_df['Polarity'] < 0]
negative_df
# Out:
#                                                  Review  Polarity  \
# 5     The main line of defence seems to be: lighten ... -0.058730
# 14    The first time I watched "The Phantom Menace",... -0.001111
# 24    It's hard to take off your nostalgia glasses w... -0.001190
# 27    The galaxy is run by the Republic, however the... -0.088889
# 30    The Phantom Menace is one of those movies that... -0.046142
# ...                                                 ...       ...
# 3976  If this were not Star Wars this film would nev... -0.214583
# 3980  I admit that when I first saw this film in the... -0.044643
# 3984  To be honest I fell asleep when I was in the t... -0.004167
# 3985  Okay, I was way late to the party on this movi... -0.050000
# 3987  I went to see this film during it's first rele... -0.045991
#
#       Subjectivity
# 5         0.523810
# 14        0.381667
# 24        0.332143
# 27        0.627778
# 30        0.303086
# ...            ...
# 3976      0.577778
# ...

# %%
# Creates a sample dataframe of 5 percent of positive reviews
positive_df_2 = positive_df.sample(frac = .05)
# Creates a sample dataframe of 5 percent of negative reviews
negative_df_2 = negative_df.sample(frac = .05)

# %%
# Converts positive dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\Star_Wars_Episode_1_Positive_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# positive_df_2.to_csv(index=False)
# positive_df_2.to_csv(filepath)

# %%
# Converts negative dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\Star_Wars_Episode_1_Negative_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# negative_df_2.to_csv(index=False)
# negative_df_2.to_csv(filepath)
