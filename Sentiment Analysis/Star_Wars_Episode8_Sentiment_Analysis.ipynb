# %%
# Installing python libraries
# !pip install -U textblob
# !python -m textblob.download_corpora
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 636 kB 5.1 MB/s
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.15.3
#     Uninstalling textblob-0.15.3:
#       Successfully uninstalled textblob-0.15.3
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# ...

# %%
# Importing pandas and reading in webs scraped IMDB reviews file for episode 8
import pandas as pd
star_wars_8_df = pd.read_csv('/content/INST737_Star_Wars_IMDB_StarWars8.csv')

# %%
# Prints the first few columns
star_wars_8_df.head()
# Out:
#    Unnamed: 0       Review_Date           Author  Rating  \
# 0           0  24 December 2017      BA_Harrison     3.0
# 1           1  16 December 2017  view_and_review     3.0
# 2           2   21 January 2018      gogoschka-1     NaN
# 3           3     19 April 2021           mn2000     1.0
# 4           4  17 December 2017         marc5477     1.0
#
#                                         Review_Title  \
# 0   I'm going to keep this short (unlike the film...
# 1        Not this Disappointed Since Jar Jar Binks\n
# 2   My Issues With The Storytelling in The Last J...
# 3          An embarrassment for the Star Wars fans\n
# 4                          What the hell was this?\n
#
#                                               Review  \
# 0  After George Lucas's execrable prequels and th...
# 1  I love the Star Wars franchise. I was so anxio...
# 2  I didn't hate TLJ, but even if I completely ig...
# 3  When I watch this movie, it only makes me reme...
# ...

# %%
# Drops unneeded columns 
star_wars_8_df_v2 = star_wars_8_df.drop(columns = ["Review_Date", "Author", "Rating", "Review_Title", "Review_Url", "Unnamed: 0"])

# %%
# Prints newly edited dataframe
star_wars_8_df_v2
# Out:
#                                                  Review
# 0     After George Lucas's execrable prequels and th...
# 1     I love the Star Wars franchise. I was so anxio...
# 2     I didn't hate TLJ, but even if I completely ig...
# 3     When I watch this movie, it only makes me reme...
# 4     Wow this is getting hammered by reviews and no...
# ...                                                 ...
# 7081  I love how the main music theme is based upon ...
# 7082  Episode 8 was a very interesting movie. It was...
# 7083  No spoilers, but If you haven't seen The Last ...
# 7084  I'd describe The Last Jedi as a bad good movie...
# 7085  The Last Jedi is a little frustrating to watch...
#
# [7086 rows x 1 columns]

# %%
# Test block to see if review gets printed
reviewParagraph = ""
for review in star_wars_8_df_v2['Review'][:1]:
  reviewParagraph = review

# %%
# Prints results from previous test for loop 
reviewParagraph
# Out:
# "After George Lucas's execrable prequels and the mediocre The Force Awakens, I've learnt to keep my expectations low for any new Star Wars films in order to avoid total disappointment. Having just seen The Last Jedi, it appears that I haven't been keeping them low enough."

# %%
# Imports TextBlob
from textblob import TextBlob
blob = TextBlob(reviewParagraph)

# %%
# This block was used for testing purposes to see if the first review's sentiment and polarity would get displayed
blob.sentiment
# Out:
# Sentiment(polarity=-0.12045454545454545, subjectivity=0.4714015151515152)

# %%
# Creates dataframe that will be used to get the sentiment and polarity of all star wars episode 8 reviews
star_wars_episode_8_final_df = pd.DataFrame(columns = ['Review', 'Polarity', 'Subjectivity'])

# %%
# Checks to see if dataframe was created with the columns created above 
star_wars_episode_8_final_df
# Out:
# Empty DataFrame
# Columns: [Review, Polarity, Subjectivity]
# Index: []

# %%
# This block would give the polarity and subjectivity of all reviews for Star Wars episode 8
star_wars_review_list = []
star_wars_polarity_list = []
star_wars_subjectivity_list = []

for review in star_wars_8_df_v2['Review']:
  blob = TextBlob(str(review))
  star_wars_review_list.append(review)
  star_wars_polarity_list.append(blob.sentiment.polarity)
  star_wars_subjectivity_list.append(blob.sentiment.subjectivity)



star_wars_episode_8_final_df['Review'] = star_wars_review_list
star_wars_episode_8_final_df['Polarity'] = star_wars_polarity_list
star_wars_episode_8_final_df['Subjectivity'] = star_wars_subjectivity_list


star_wars_episode_8_final_df = star_wars_episode_8_final_df[['Review', 'Polarity', 'Subjectivity']]
  
star_wars_episode_8_final_df.head()
# Out:
#                                               Review  Polarity  Subjectivity
# 0  After George Lucas's execrable prequels and th... -0.120455      0.471402
# 1  I love the Star Wars franchise. I was so anxio...  0.130556      0.572222
# 2  I didn't hate TLJ, but even if I completely ig...  0.085714      0.700000
# 3  When I watch this movie, it only makes me reme...  0.393750      0.681250
# 4  Wow this is getting hammered by reviews and no...  0.050000      0.700000

# %%
# Converting dataframe to csv 
# Code down below was commented out because file already created 
# star_wars_episode8_final_df.to_csv('Star_Wars_Episode8_Sentiment_Analysis.csv’)

# %%
# Reviews that have a polarity greater than 0 go to a positive dataframe
positive_df = star_wars_episode_8_final_df[star_wars_episode_8_final_df['Polarity'] > 0]
positive_df
# Out:
#                                                  Review  Polarity  \
# 1     I love the Star Wars franchise. I was so anxio...  0.130556
# 2     I didn't hate TLJ, but even if I completely ig...  0.085714
# 3     When I watch this movie, it only makes me reme...  0.393750
# 4     Wow this is getting hammered by reviews and no...  0.050000
# 7     Modern Disney - you know, the one that has to ...  0.347619
# ...                                                 ...       ...
# 7081  I love how the main music theme is based upon ...  0.199640
# 7082  Episode 8 was a very interesting movie. It was...  0.233333
# 7083  No spoilers, but If you haven't seen The Last ...  0.099907
# 7084  I'd describe The Last Jedi as a bad good movie...  0.061782
# 7085  The Last Jedi is a little frustrating to watch...  0.024702
#
#       Subjectivity
# 1         0.572222
# 2         0.700000
# 3         0.681250
# 4         0.700000
# 7         0.664286
# ...            ...
# 7081      0.469912
# ...

# %%
# Reviews that have a polarity less than 0 go to a negative dataframe
negative_df = star_wars_episode_8_final_df[star_wars_episode_8_final_df['Polarity'] < 0]
negative_df
# Out:
#                                                  Review  Polarity  \
# 0     After George Lucas's execrable prequels and th... -0.120455
# 5     Picking up where The Force Awakens left off, R... -0.006944
# 8     Its so bad it doesn't deserve a proper review.... -0.350000
# 13    I am so sorry that for the first time in my li... -0.126429
# 17    I didn't like Star Wars: The Last Jedi and I'm... -0.049660
# ...                                                 ...       ...
# 7062  Recently saw the new Star Wars, went in with a... -0.153896
# 7065  While I was very entertained by the Last Jedi,... -0.066667
# 7072  I think that the movie could be a lot better i... -0.171928
# 7078  Short - a very disjointed plot that fails to g... -0.100000
# 7080  I'm a huge Starwars fan. I have seen alle movi... -0.005556
#
#       Subjectivity
# 0         0.471402
# 5         0.215278
# 8         0.383333
# 13        0.561905
# 17        0.436054
# ...            ...
# 7062      0.446537
# ...

# %%
# Creates a sample dataframe of 5 percent of positive reviews
positive_df_2 = positive_df.sample(frac = .05)
# Creates a sample dataframe of 5 percent of negative reviews
negative_df_2 = negative_df.sample(frac = .05)

# %%
# Converts positive dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\Star_Wars_Episode_8_Positive_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# positive_df_2.to_csv(index=False)
# positive_df_2.to_csv(filepath)

# %%
# Converts negative dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\Star_Wars_Episode_8_Negative_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# negative_df_2.to_csv(index=False)
# negative_df_2.to_csv(filepath)
