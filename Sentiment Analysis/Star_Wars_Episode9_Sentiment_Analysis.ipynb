# %%
# Installing python libraries
# !pip install -U textblob
# !python -m textblob.download_corpora
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 636 kB 4.8 MB/s
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.15.3
#     Uninstalling textblob-0.15.3:
#       Successfully uninstalled textblob-0.15.3
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# ...

# %%
# Importing pandas and reading in webs scraped IMDB reviews file for episode 9
import pandas as pd
star_wars_9_df = pd.read_csv("/content/INST737_Star_Wars_IMDB_StarWars9.csv")

# %%
# Prints the first few columns
star_wars_9_df.head()
# Out:
#    Unnamed: 0       Review_Date            Author  Rating  \
# 0           0  20 December 2019  BandSAboutMovies     4.0
# 1           1  21 December 2019        ben_busche     4.0
# 2           2   2 February 2021    Prichards12345     1.0
# 3           3    5 January 2020   danielkanemusic     2.0
# 4           4       18 May 2020    arapacis-metal     NaN
#
#                                         Review_Title  \
# 0                                          Oh well\n
# 1   RIP Star Wars. Every inconsistency listed bel...
# 2                                    Utter Garbage\n
# 3                      The RISE (???) of Skywalker\n
# 4   Disney And JJ Abrams Completely Misunderstand...
#
#                                               Review  \
# 0  Three movies in to the final part of what is b...
# 1  This movie introduced an absurd amount of inco...
# 2  A hot mess of a movie, with terrible writing, ...
# 3                   The good:\nCinematography\nMusic
# ...

# %%
# Drops unneeded columns 
star_wars_9_df_v2 = star_wars_9_df.drop(columns = ["Review_Date", "Author", "Rating", "Review_Title", "Review_Url", "Unnamed: 0"])

# %%
# Prints newly edited dataframe
star_wars_9_df_v2
# Out:
#                                                  Review
# 0     Three movies in to the final part of what is b...
# 1     This movie introduced an absurd amount of inco...
# 2     A hot mess of a movie, with terrible writing, ...
# 3                      The good:\nCinematography\nMusic
# 4     They are so used to making films for four-year...
# ...                                                 ...
# 8046  Alright now I get why hardcore fans are mad ab...
# 8047  First of all, I am a big fan, but not a die-ha...
# 8048  Very well written. Action packed. Good cinemat...
# 8049  I can't believe people are actually giving thi...
# 8050  I think, that despite the fact that in some po...
#
# [8051 rows x 1 columns]

# %%
# Test block to see if review gets printed
reviewParagraph = ""
for review in star_wars_9_df_v2['Review'][:1]:
  reviewParagraph = review

# %%
# Prints results from previous test for loop 
reviewParagraph
# Out:
# "Three movies in to the final part of what is being called the Skywalker Saga and I have to confess: worse than not knowing anything about these new characters -- Poe Dameron, Finn and Rey -- I honestly don't care about them. They're ciphers that we only know the barest of things about. Why does Finn have such an affinity for his friends? Why should we care a lick about Poe when he's proven to be too headstrong and willing to leave people behind, yet has nothing redeeming to make up for it? And Rey has every single skill of the Jedi near-instantly, almost a way too perfect character to be true."

# %%
# Imports TextBlob
from textblob import TextBlob
blob = TextBlob(reviewParagraph)

# %%
# This block was used for testing purposes to see if the first review's sentiment and polarity would get displayed
blob.sentiment
# Out:
# Sentiment(polarity=0.16374458874458875, subjectivity=0.6890692640692642)

# %%
# Creates dataframe that will be used to get the sentiment and polarity of all star wars episode 9 reviews
star_wars_episode_9_final_df = pd.DataFrame(columns = ['Review', 'Polarity', 'Subjectivity'])

# %%
# Checks to see if dataframe was created with the columns created above 
star_wars_episode_9_final_df
# Out:
# Empty DataFrame
# Columns: [Review, Polarity, Subjectivity]
# Index: []

# %%
# This block would give the polarity and subjectivity of all reviews for Star Wars episode 9
star_wars_review_list = []
star_wars_polarity_list = []
star_wars_subjectivity_list = []

for review in star_wars_9_df_v2['Review']:
  blob = TextBlob(str(review))
  star_wars_review_list.append(review)
  star_wars_polarity_list.append(blob.sentiment.polarity)
  star_wars_subjectivity_list.append(blob.sentiment.subjectivity)



star_wars_episode_9_final_df['Review'] = star_wars_review_list
star_wars_episode_9_final_df['Polarity'] = star_wars_polarity_list
star_wars_episode_9_final_df['Subjectivity'] = star_wars_subjectivity_list


star_wars_episode_9_final_df = star_wars_episode_9_final_df[['Review', 'Polarity', 'Subjectivity']]
  
star_wars_episode_9_final_df.head()
# Out:
#                                               Review  Polarity  Subjectivity
# 0  Three movies in to the final part of what is b...  0.163745      0.689069
# 1  This movie introduced an absurd amount of inco...  0.076190      0.433333
# 2  A hot mess of a movie, with terrible writing, ... -0.165000      0.505000
# 3                   The good:\nCinematography\nMusic  0.700000      0.600000
# 4  They are so used to making films for four-year...  0.168750      0.775000

# %%
# Converting dataframe to csv 
# Code down below was commented out because file already created 
# star_wars_episode9_final_df.to_csv('Star_Wars_Episode9_Sentiment_Analysis.csv’)

# %%
# Reviews that have a polarity greater than 0 go to a positive dataframe
positive_df = star_wars_episode_9_final_df[star_wars_episode_9_final_df['Polarity'] > 0]
positive_df
# Out:
#                                                  Review  Polarity  \
# 0     Three movies in to the final part of what is b...  0.163745
# 1     This movie introduced an absurd amount of inco...  0.076190
# 3                      The good:\nCinematography\nMusic  0.700000
# 4     They are so used to making films for four-year...  0.168750
# 5     I LOVE Star Wars films and couldn't see this f...  0.009444
# ...                                                 ...       ...
# 8044  Very fun Star Wars film with some scenes of co...  0.466667
# 8045  I remember seeing A New Hope with my Dad in th...  0.289797
# 8046  Alright now I get why hardcore fans are mad ab...  0.169444
# 8047  First of all, I am a big fan, but not a die-ha...  0.202500
# 8048  Very well written. Action packed. Good cinemat...  0.331250
#
#       Subjectivity
# 0         0.689069
# 1         0.433333
# 3         0.600000
# 4         0.775000
# 5         0.718889
# ...            ...
# 8044      0.380000
# ...

# %%
# Reviews that have a polarity less than 0 go to a negative dataframe
negative_df = star_wars_episode_9_final_df[star_wars_episode_9_final_df['Polarity'] < 0]
negative_df
# Out:
#                                                  Review      Polarity  \
# 2     A hot mess of a movie, with terrible writing, ... -1.650000e-01
# 6     A tragic culmination of the flaws of the previ... -8.690476e-02
# 13    This movie was just straight-up painful to wat... -3.642857e-01
# 15    Letting JJ whatever his name is and Rian Johns... -5.333333e-01
# 21    I had a thought watching this, "How did Disney... -3.562500e-01
# ...                                                 ...           ...
# 8029  From now on, no Star Wars movie should begin w... -5.333333e-01
# 8031  This is horrible. The last Skywalker died in t... -6.666667e-02
# 8040  Visuals and music are very good. But story des... -1.308333e-01
# 8049  I can't believe people are actually giving thi... -1.562500e-01
# 8050  I think, that despite the fact that in some po... -5.551115e-18
#
#       Subjectivity
# 2         0.505000
# 6         0.536905
# 13        0.735268
# 15        0.688889
# 21        0.550000
# ...

# %%
# Creates a sample dataframe of 5 percent of positive reviews
positive_df_2 = positive_df.sample(frac = .05)
# Creates a sample dataframe of 5 percent of negative reviews
negative_df_2 = negative_df.sample(frac = .05)

# %%
# Converts positive dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\Star_Wars_Episode_9_Positive_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# positive_df_2.to_csv(index=False)
# positive_df_2.to_csv(filepath)

# %%
# Converts negative dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\\Star_Wars_Episode_9_Negative_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# negative_df_2.to_csv(index=False)
# negative_df_2.to_csv(filepath)
