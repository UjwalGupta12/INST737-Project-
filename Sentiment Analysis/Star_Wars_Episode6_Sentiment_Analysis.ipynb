# %%
# Installing python libraries
# !pip install -U textblob
# !python -m textblob.download_corpora
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 636 kB 5.1 MB/s
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.15.3
#     Uninstalling textblob-0.15.3:
#       Successfully uninstalled textblob-0.15.3
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# ...

# %%
# Importing pandas and reading in webs scraped IMDB reviews file for episode 6
import pandas as pd
star_wars_6_df = pd.read_csv("/content/INST737_Star_Wars_IMDB_StarWars6.csv")

# %%
# Prints the first few columns
star_wars_6_df.head()
# Out:
#    Unnamed: 0       Review_Date           Author  Rating  \
# 0           0   16 January 2020   UniqueParticle    10.0
# 1           1   2 December 2005     evanston_dad    10.0
# 2           2  12 February 2006  ccthemovieman-1     9.0
# 3           3     30 March 2020       bevo-13678    10.0
# 4           4     28 April 2016       ivo-cobra8     8.0
#
#                                         Review_Title  \
# 0   The most peculiar Star Wars and under appreci...
# 1                    The Boy Who Loved "Star Wars"\n
# 2                    One Of The Best In The Series\n
# 3                                             Good\n
# 4   Flawed, very entertaining solid third sequel ...
#
#                                               Review  \
# 0  Totally should've won at least some of the awa...
# 1  A long time ago, in a galaxy far, far away.......
# 2  Up until the sixth and last episode of the Sta...
# 3  I like the bit when the ewoks crush an ATST wi...
# ...

# %%
# Drops unneeded columns 
star_wars_6_df_v2 = star_wars_6_df.drop(columns = ["Review_Date", "Author", "Rating", "Review_Title", "Review_Url", "Unnamed: 0"])

# %%
# Prints newly edited dataframe
star_wars_6_df_v2
# Out:
#                                                 Review
# 0    Totally should've won at least some of the awa...
# 1    A long time ago, in a galaxy far, far away.......
# 2    Up until the sixth and last episode of the Sta...
# 3    I like the bit when the ewoks crush an ATST wi...
# 4    Star Wars: Episode VI – Return of the Jedi (19...
# ..                                                 ...
# 935  I was never into the star wars films so i neve...
# 936  A couple of weeks ago I had (again) the opport...
# 937  As a cub viewing the scene where father saves ...
# 938  As Most Off You Might off Seen Star Wars: Retu...
# 939  Aburrido, lo mismo de siempre, androides, futu...
#
# [940 rows x 1 columns]

# %%
# Test block to see if review gets printed
reviewParagraph = ""
for review in star_wars_6_df_v2['Review'][:1]:
  reviewParagraph = review

# %%
# Prints results from previous test for loop 
reviewParagraph
# Out:
# "Totally should've won at least some of the awards it was nominated for! A very different adventure story with lots of adorable characters, more truths and the epic Emperor Palpatine! I love all the majestic forest aspects. Still crazy to me that they filmed so many parts especially the chases. The bulk of this art in cinema is done so well and always entertaining. Quite lovable many years later and not many movies have that kind of force!"

# %%
# Imports TextBlob
from textblob import TextBlob
blob = TextBlob(reviewParagraph)

# %%
# This block was used for testing purposes to see if the first review's sentiment and polarity would get displayed
blob.sentiment
# Out:
# Sentiment(polarity=0.196875, subjectivity=0.6206250000000001)

# %%
# Creates dataframe that will be used to get the sentiment and polarity of all star wars episode 6 reviews
star_wars_episode_6_final_df = pd.DataFrame(columns = ['Review', 'Polarity', 'Subjectivity'])

# %%
# Checks to see if dataframe was created with the columns created above 
star_wars_episode_6_final_df
# Out:
# Empty DataFrame
# Columns: [Review, Polarity, Subjectivity]
# Index: []

# %%
# This block would give the polarity and subjectivity of all reviews for Star Wars episode 6
star_wars_review_list = []
star_wars_polarity_list = []
star_wars_subjectivity_list = []

for review in star_wars_6_df_v2['Review']:
  blob = TextBlob(str(review))
  star_wars_review_list.append(review)
  star_wars_polarity_list.append(blob.sentiment.polarity)
  star_wars_subjectivity_list.append(blob.sentiment.subjectivity)



star_wars_episode_6_final_df['Review'] = star_wars_review_list
star_wars_episode_6_final_df['Polarity'] = star_wars_polarity_list
star_wars_episode_6_final_df['Subjectivity'] = star_wars_subjectivity_list


star_wars_episode_6_final_df = star_wars_episode_6_final_df[['Review', 'Polarity', 'Subjectivity']]
  
star_wars_episode_6_final_df.head()
# Out:
#                                               Review  Polarity  Subjectivity
# 0  Totally should've won at least some of the awa...  0.196875      0.620625
# 1  A long time ago, in a galaxy far, far away.......  0.175779      0.462316
# 2  Up until the sixth and last episode of the Sta...  0.183333      0.544444
# 3  I like the bit when the ewoks crush an ATST wi...  0.000000      0.000000
# 4  Star Wars: Episode VI – Return of the Jedi (19...  0.257115      0.562436

# %%
# Converting dataframe to csv 
# Code down below was commented out because file already created 
# star_wars_episode6_final_df.to_csv('Star_Wars_Episode6_Sentiment_Analysis.csv’)

# %%
# Reviews that have a polarity greater than 0 go to a positive dataframe
positive_df = star_wars_episode_6_final_df[star_wars_episode_6_final_df['Polarity'] > 0]
positive_df
# Out:
#                                                 Review  Polarity  Subjectivity
# 0    Totally should've won at least some of the awa...  0.196875      0.620625
# 1    A long time ago, in a galaxy far, far away.......  0.175779      0.462316
# 2    Up until the sixth and last episode of the Sta...  0.183333      0.544444
# 4    Star Wars: Episode VI – Return of the Jedi (19...  0.257115      0.562436
# 5    This movie might not be as flawless as the fir...  0.291176      0.628922
# ..                                                 ...       ...           ...
# 934  I have enjoyed all of the Star Wars films, but...  0.229167      0.632407
# 935  I was never into the star wars films so i neve...  0.281250      0.466667
# 936  A couple of weeks ago I had (again) the opport...  0.152847      0.564167
# 937  As a cub viewing the scene where father saves ...  0.350000      0.600000
# 938  As Most Off You Might off Seen Star Wars: Retu...  0.134304      0.323438
#
# [789 rows x 3 columns]

# %%
# Reviews that have a polarity less than 0 go to a negative dataframe
negative_df = star_wars_episode_6_final_df[star_wars_episode_6_final_df['Polarity'] < 0]
negative_df
# Out:
#                                                 Review  Polarity  Subjectivity
# 10   Star Wars: Episode VI - Return of the Jedi (19... -0.041667      0.555556
# 15   Long ago, in a Galaxy far away came a film whi... -0.091667      0.704167
# 47   The third parts of trilogies tend to be inferi... -0.069231      0.424359
# 63   "Star Wars VI: Return of the Jedi" (1983) was ... -0.036905      0.554762
# 72   I mean.. as I said with my review of "A New Ho... -0.072348      0.499513
# ..                                                 ...       ...           ...
# 874  What a shame, that they wasted so much screen ... -0.078125      0.233333
# 897  I love STARWARS...Episode IV & V my fav and RO... -0.028409      0.603409
# 902  I have just seen The return of the Jedi in Fox... -0.000468      0.499599
# 906                             *Minor spoilers ahead* -0.050000      0.200000
# 928  I thought the Vader star destroyer space shutt... -0.100000      0.700417
#
# [107 rows x 3 columns]

# %%
# Creates a sample dataframe of 5 percent of positive reviews
positive_df_2 = positive_df.sample(frac = .05)
# Creates a sample dataframe of 5 percent of negative reviews
negative_df_2 = negative_df.sample(frac = .05)

# %%
# Converts positive dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\\Star_Wars_Episode_6_Positive_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# positive_df_2.to_csv(index=False)
# positive_df_2.to_csv(filepath)

# %%
# Converts negative dataframe to csv
# Code down below was commented out because file already created 
# from pathlib import Path  
# filepath = Path('C:\\Users\\ujwal\\Downloads\\\Star_Wars_Episode_6_Negative_Sentiment_df.csv')  
# filepath.parent.mkdir(parents=True, exist_ok=True)  
# negative_df_2.to_csv(index=False)
# negative_df_2.to_csv(filepath)
