# %%
#!pip install selenium
#!pip install scrapy

# %%
import numpy as np
import pandas as pd
from scrapy.selector import Selector
from selenium import webdriver 
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")
import random

# %%
driver = webdriver.Chrome(r'D:\UMD Master Year 2 College Work\Fall 2022-2023\INST737-IM01\chromedriver')
url = 'https://www.imdb.com/title/tt0076759/reviews?ref_=tt_ov_rt' 
randomNumber = random.randint(0,4)
time.sleep(1)
driver.get(url)
time.sleep(1)
print(driver.title)
time.sleep(1)
body = driver.find_element(By.CSS_SELECTOR, 'body')
body.send_keys(Keys.END)
time.sleep(randomNumber)
# body.send_keys(Keys.PAGE_DOWN)
# time.sleep(1)
# body.send_keys(Keys.PAGE_DOWN)
# time.sleep(1)
# body.send_keys(Keys.PAGE_DOWN)
# Out:
# Star Wars: Episode IV - A New Hope (1977) - Star Wars: Episode IV - A New Hope (1977) - User Reviews - IMDb

# %%
sel = Selector(text = driver.page_source)
review_counts = sel.css('.lister .header span::text').extract_first().replace(',','').split(' ')[0]
more_review_pages = int(int(review_counts)/25)

# %%
for i in tqdm(range(more_review_pages)):
    try:
        css_selector = 'load-more-trigger'
        driver.find_element(By.ID, css_selector).click()
        body.send_keys(Keys.END)
        time.sleep(randomNumber)
    except:
        pass
# Out:
# 100%|██████████| 83/83 [02:10<00:00,  1.57s/it]

# %%
reviews = driver.find_elements(By.CSS_SELECTOR, 'div.review-container')
first_review = reviews[0]
sel2 = Selector(text = first_review.get_attribute('innerHTML'))
rating = sel2.css('.rating-other-user-rating span::text').extract_first().strip()

# %%
review = sel2.css('.text.show-more__control::text').extract_first().strip()
review_date = sel2.css('.review-date::text').extract_first().strip()
author = sel2.css('.display-name-link a::text').extract_first().strip()
review_title = sel2.css('a.title::text').extract_first().strip()
review_url = sel2.css('a.title::attr(href)').extract_first().strip()
#helpfulness = sel2.css('.actions.text-muted::text').extract_first().strip()
print('nRating:',rating)
print('nreview_title:',review_title)
print('nAuthor:',author)
print('nreview_date:',review_date)
print('nreview:',review)
#print('nhelpfulness:',helpfulness)
# Out:
# nRating: 10
# nreview_title: One of the most successful movies of all time (and I'm not talking about the Box Office take)
# nAuthor: FiendishDramaturgy
# nreview_date: 26 October 2003
# nreview: What made this the hugely successful triumph it was? Was it casting, music, imagination, ingenuity, or luck?

# %%
rating_list = []
review_date_list = []
review_title_list = []
author_list = []
review_list = []
review_url_list = []
error_url_list = []
error_msg_list = []
reviews = driver.find_elements(By.CSS_SELECTOR, 'div.review-container')

for d in tqdm(reviews):
    try:
        sel2 = Selector(text = d.get_attribute('innerHTML'))
        try:
            rating = sel2.css('.rating-other-user-rating span::text').extract_first()
        except:
            rating = np.NaN
        try:
            review = sel2.css('.text.show-more__control::text').extract_first()
        except:
            review = np.NaN
        try:
            review_date = sel2.css('.review-date::text').extract_first()
        except:
            review_date = np.NaN    
        try:
            author = sel2.css('.display-name-link a::text').extract_first()
        except:
            author = np.NaN    
        try:
            review_title = sel2.css('a.title::text').extract_first()
        except:
            review_title = np.NaN
        try:
            review_url = sel2.css('a.title::attr(href)').extract_first()
        except:
            review_url = np.NaN
        rating_list.append(rating)
        review_date_list.append(review_date)
        review_title_list.append(review_title)
        author_list.append(author)
        review_list.append(review)
        review_url_list.append(review_url)
    except Exception as e:
        error_url_list.append(url)
        error_msg_list.append(e)
review_df = pd.DataFrame({
    'Review_Date':review_date_list,
    'Author':author_list,
    'Rating':rating_list,
    'Review_Title':review_title_list,
    'Review':review_list,
    'Review_Url':review_url
    })
# Out:
# 100%|██████████| 2057/2057 [01:37<00:00, 21.20it/s]

# %%
review_df
# Out:
#             Review_Date              Author Rating  \
# 0       26 October 2003  FiendishDramaturgy     10
# 1         23 April 2016          ivo-cobra8     10
# 2       16 January 2020      UniqueParticle     10
# 3      25 December 2005          Bogmeister      9
# 4         31 March 2003        mentalcritic   None
# ...                 ...                 ...    ...
# 2052      26 April 2018      evandone-02501      9
# 2053     12 August 2022          slee-73937      8
# 2054  27 September 2018           TJMdeBoer     10
# 2055  26 September 2018   matthewchristiano      9
# 2056    12 January 2019         patpeatrick     10
#
#                                            Review_Title  \
# 0      One of the most successful movies of all time...
# 1      A classics, phenomenal and arguably the best ...
# 2                           Legendary piece of cinema\n
# 3      The Best of Sci-Fi Times,the Worst of sf Times\n
# 4               The original version was brilliant...\n
# ...                                                 ...
# 2052                                            Great\n
# 2053                                 Enjoyable still.\n
# 2054                                    Small revieuw\n
# 2055                            Review for Film Class\n
# 2056                         The Holy Trilogy, et al.\n
#
#                                                  Review  \
# 0     What made this the hugely successful triumph i...
# 1     Star Wars: Episode IV - A New Hope (1977) is a...
# 2     Only seen the original Star Wars films a few t...
# 3     Though now known as "Episode IV-A New Hope," f...
# 4     I was actually born about a year after this fi...
# ...                                                 ...
# 2052  Great movie, ive watched it millions of times ...
# 2053  Is this a great film, probably not. However it...
# 2054  I personaly like this movie the most because i...
# 2055  Star Wars: Episode IV - A New Hope follows the...
# 2056  It's near impossible to select a favorite from...
#
#                           Review_Url
# 0     /review/rw4576354/?ref_=tt_urv
# 1     /review/rw4576354/?ref_=tt_urv
# 2     /review/rw4576354/?ref_=tt_urv
# 3     /review/rw4576354/?ref_=tt_urv
# 4     /review/rw4576354/?ref_=tt_urv
# ...                              ...
# 2052  /review/rw4576354/?ref_=tt_urv
# 2053  /review/rw4576354/?ref_=tt_urv
# 2054  /review/rw4576354/?ref_=tt_urv
# 2055  /review/rw4576354/?ref_=tt_urv
# 2056  /review/rw4576354/?ref_=tt_urv
#
# [2057 rows x 6 columns]

# %%
#2086 reviews

# %%
#review_df.to_csv(r'D:\UMD Master Year 2 College Work\Fall 2022-2023\INST737-IM01\INST737_Star_Wars_IMDB_StarWars4.csv')
